# %%
import matplotlib

# %%
ls -t
# Out:
# Untitled0.ipynb
# Average_NB_Data.py*
# NB14_SingleGenes_STD_SingleGenes.py*
# NB14_SingleGenes_STD_CommandLIne.py
# NB14_SingleGenes_STD_140423.py*
# PD6.pdf
# PU6.pdf
# ND6.png
# NU6.png
# General_STD_analysis_control.pyc
# General_STD_analysis_control.py*
# NB14_STD_Comparison_Graph_Scatter.py*
# NB14_SingleGenes_SGNC_140423.py*
# NB_SaveToFile.py*
# STD_Functions.pyc
# STD_Functions.py*
# test
# NB14_SingleGenes_TPM_One_140423.py*
# NB14_SingleGenes_StableGenes.py*
# ND6.pdf
# NU6.pdf
# NB14_SingleGenes_TPM_140423.py*
# NB14_SingleGenes_SGNC_Test.py*
# test.txt
# tmp
# GetDif_GeneNames.py*
# NB14_SingleGenes_TPM.py*
# trinity_assembly_Cosci_Norm2_130315.sh*
# NB14_SingleGenes_SGNC_CommandLIne.py
# NB14_SingleGenes_SGNC_ByDate.py*
# NB14_SingleGenes_SGNC.py*
# NB14_SingleGenes_STD.py*
# test.fa
# NB14_SingleGenes_STD (Harriet's computer's conflicted copy 2014-03-01).py*
# NB_141020_PickleData.py*
# NB14_SingleGenes.py*
# NB14_STDPLOT_SingleGenes.py*
# OlderScripts/
# STD_Analysis_NB140220.py*

# %%
# %matplotlib inline

# %%
# %load  NB14_SingleGenes_STD_SingleGenes.py

# %%
#!/usr/bin/env python

'''
Created on November 9, 2013

Comparison script for Throt and Skcos count data; calls upon general and std functions 

@author: harrietalexander
'''
import math
import sys
import glob
import os
import numpy as np
import re
import csv
import matplotlib.pylab as plt
import matplotlib.cm as cm
import STD_Functions as STD
import General_STD_analysis_control as GSTD
import pickle
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
#Relies upon the Genearl and STD_functions python files. 
#Location of pickled files
PickleOutDir="/Users/harrietalexander/Dropbox/NB_141020/PickledData/"

#Throt_filenames from pickle
Throt_Pk_Count=['Throt_raw', 'Throt_tpm', 'Throt_SGNC', 'Throt_GeneList']
Throt_Pk_STD=['Throt_PupP_STD', 'Throt_PupN_STD', 'Throt_PdnP_STD', 'Throt_PdnN_STD', 'Throt_NupP_STD', 'Throt_NupN_STD', 'Throt_NdnP_STD', 'Throt_NdnN_STD', 'Throt_All_P', 'Throt_All_N']

#Skcos Raw Data

#Skcos filenames from pickle
Skcos_Pk_Count=['Skcos_raw', 'Skcos_tpm', 'Skcos_SGNC', 'Skcos_GeneList']
Skcos_Pk_STD=['Skcos_PupP_STD', 'Skcos_PupN_STD', 'Skcos_PdnP_STD', 'Skcos_PdnN_STD', 'Skcos_NupP_STD', 'Skcos_NupN_STD', 'Skcos_NdnP_STD', 'Skcos_NdnN_STD', 'Skcos_All_P', 'Skcos_All_N']

#Get STD_all-- from pickle. 
[Throt_raw, Throt_tpm, Throt_SGNC, Throt_GeneList]=STD.unPickleAll(Throt_Pk_Count, PickleOutDir)

[Throt_PupP_STD, Throt_PupN_STD, Throt_PdnP_STD, Throt_PdnN_STD, Throt_NupP_STD, Throt_NupN_STD, Throt_NdnP_STD, Throt_NdnN_STD, Throt_All_P, Throt_All_N]=STD.unPickleAll(Throt_Pk_STD, PickleOutDir)
[Skcos_PupP_STD, Skcos_PupN_STD, Skcos_PdnP_STD, Skcos_PdnN_STD, Skcos_NupP_STD, Skcos_NupN_STD, Skcos_NdnP_STD, Skcos_NdnN_STD, Skcos_All_P, Skcos_All_N]=STD.unPickleAll(Skcos_Pk_STD, PickleOutDir)


[Skcos_raw, Skcos_tpm, Skcos_SGNC, Skcos_GeneList]=STD.unPickleAll(Skcos_Pk_Count, PickleOutDir)




#---- Si-related genes *************************************

Pfile='/Users/harrietalexander/Dropbox/NB_141020/FinalSingleGeneFigures/NovelP.tab'
Preader=csv.reader(open(Pfile),delimiter='\t')

Phash={}
for line in Preader:
	key = line[0].strip()
	item=line[1].strip()
	if key in Phash: 
		Phash[key].append(item)
	else:
		Phash[key]=[item]


snames=['S1', 'S2', 'S3', 'S4', 'S5']
inames=['+N','-N','+P','-P', 'C']
x=range(10)
outDir='/Users/harrietalexander/Dropbox/NB_141020/FinalSingleGeneFigures/'
N=1
for ref in Phash:
	N+=1
	F=plt.figure(N)
	F.set_size_inches(5,4)
	ax1=F.add_subplot(111)
	#ax2=F.add_subplot(212)
	for item in Phash[ref]:
		ax1.set_xlim([-.5, 4.5])
		ax1.set_xticks(x[:5])
		ax1.set_xticklabels(snames)
# 		ax2.set_xlim([4.5, 9.5])
# 		ax2.set_xticks(x[5:])
# 		ax2.set_xticklabels(inames)
# 		ax1.set_ylim([-20,20])
		##ax1.set_ylim([0,10])
		#ax2.set_ylim([0,0.4])


		PUpNDn='#FF33CC'
		NUp='#FF9900'
		NDn='#0000CC'
		PUp='#00FF00'
		PDn='#FFFF99'
		NRG='0.75'
		Throt_UpPDnN=list(set(Throt_GeneList['P_Genes'][1]).intersection(Throt_GeneList['N_Genes'][0]))
		Skcos_UpPDnN=list(set(Skcos_GeneList['P_Genes'][1]).intersection(Skcos_GeneList['N_Genes'][0]))

		
		
		Throt_SGNC=Throt_All_P
		Skcos_SGNC=Skcos_All_P
		if re.search('Throt', item):	
			if any(item==s for s in Throt_UpPDnN):
				ax1.plot(x[:5],Throt_SGNC[item][:5], ls='--', color=PUpNDn, marker='o', mec=PUpNDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PUpNDn, marker='o', mec=PUpNDn, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['P_Genes'][1]):
			 	ax1.plot(x[:5],Throt_SGNC[item][:5], ls='--', color=PUp, marker='o', mec=PUp, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PUp, marker='o', mec=PUp, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['P_Genes'][0]):
			 	ax1.plot(x[:5],Throt_SGNC[item][:5],ls='--', color=PDn, marker='o', mec=PDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PDn, marker='o', mec=PDn, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['N_Genes'][1]):
			 	ax1.plot(x[:5],Throt_SGNC[item][:5], ls='--',color=NUp, marker='o', mec=NUp, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None', color=NUp, marker='o', mec=NUp, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['N_Genes'][0]):
			 	ax1.plot(x[:5],Throt_SGNC[item][:5], ls='--', color=NDn, marker='o', mec=NDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=NDn, marker='o', mec=NDn, ms=12,linewidth=3)
			else:
				ax1.plot(x[:5],Throt_SGNC[item][:5], ls='--',color=NRG, marker='o',mec=NRG, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=NRG, marker='o',mec=NRG, ms=12,linewidth=3)
			 	

		elif re.search('Skcos', item):
			if any(item==s for s in Skcos_UpPDnN):
				ax1.plot(x[:5],Skcos_SGNC[item][:5], ls='-', color=PUpNDn, marker='^', mec=PUpNDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PUpNDn, marker='^', mec=PUpNDn, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['P_Genes'][1]):
			 	ax1.plot(x[:5],Skcos_SGNC[item][:5], ls='-', color=PUp, marker='^', mec=PUp, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PUp, marker='^', mec=PUp, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['P_Genes'][0]):
			 	ax1.plot(x[:5],Skcos_SGNC[item][:5],ls='-', color=PDn, marker='^', mec=PDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PDn, marker='^', mec=PDn, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['N_Genes'][1]):
			 	ax1.plot(x[:5],Skcos_SGNC[item][:5], ls='-',color=NUp, marker='^', mec=NUp, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None', color=NUp, marker='^', mec=NUp, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['N_Genes'][0]):
			 	ax1.plot(x[:5],Skcos_SGNC[item][:5], ls='-', color=NDn, marker='^', mec=NDn, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=NDn, marker='^', mec=NDn, ms=12,linewidth=3)
			else:
				ax1.plot(x[:5],Skcos_SGNC[item][:5], ls='-',color=NRG, marker='^',mec=NRG, ms=12,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=NRG, marker='^',mec=NRG, ms=12,linewidth=3)
			 	
	ax1.set_xlabel('Sample',fontsize=14)
	ax1.set_ylabel('STD-N', fontsize=14)
			 	
	plt.suptitle(ref,fontsize=16)
	plt.savefig(outDir+ref+'_SingleGenes_STDN.pdf')


plt.show()

# %%
#!/usr/bin/env python

'''
Created on November 9, 2013

Comparison script for Throt and Skcos count data; calls upon general and std functions 

@author: harrietalexander
'''
import math
import sys
import glob
import os
import numpy as np
import re
import csv
import matplotlib.pylab as plt
import matplotlib.cm as cm
import STD_Functions as STD
import General_STD_analysis_control as GSTD
import pickle
import matplotlib as mpl
import brewer2mpl
mpl.rcParams['pdf.fonttype'] = 42
#Relies upon the Genearl and STD_functions python files. 
#Location of pickled files
PickleOutDir="/Users/harrietalexander/Dropbox/NB_141020/PickledData/"

#Throt_filenames from pickle
Throt_Pk_Count=['Throt_raw', 'Throt_tpm', 'Throt_SGNC', 'Throt_GeneList']
Throt_Pk_STD=['Throt_PupP_STD', 'Throt_PupN_STD', 'Throt_PdnP_STD', 'Throt_PdnN_STD', 'Throt_NupP_STD', 'Throt_NupN_STD', 'Throt_NdnP_STD', 'Throt_NdnN_STD', 'Throt_All_P', 'Throt_All_N']

#Skcos Raw Data

#Skcos filenames from pickle
Skcos_Pk_Count=['Skcos_raw', 'Skcos_tpm', 'Skcos_SGNC', 'Skcos_GeneList']
Skcos_Pk_STD=['Skcos_PupP_STD', 'Skcos_PupN_STD', 'Skcos_PdnP_STD', 'Skcos_PdnN_STD', 'Skcos_NupP_STD', 'Skcos_NupN_STD', 'Skcos_NdnP_STD', 'Skcos_NdnN_STD', 'Skcos_All_P', 'Skcos_All_N']

#Get STD_all-- from pickle. 
[Throt_raw, Throt_tpm, Throt_SGNC, Throt_GeneList]=STD.unPickleAll(Throt_Pk_Count, PickleOutDir)

[Throt_PupP_STD, Throt_PupN_STD, Throt_PdnP_STD, Throt_PdnN_STD, Throt_NupP_STD, Throt_NupN_STD, Throt_NdnP_STD, Throt_NdnN_STD, Throt_All_P, Throt_All_N]=STD.unPickleAll(Throt_Pk_STD, PickleOutDir)
[Skcos_PupP_STD, Skcos_PupN_STD, Skcos_PdnP_STD, Skcos_PdnN_STD, Skcos_NupP_STD, Skcos_NupN_STD, Skcos_NdnP_STD, Skcos_NdnN_STD, Skcos_All_P, Skcos_All_N]=STD.unPickleAll(Skcos_Pk_STD, PickleOutDir)


[Skcos_raw, Skcos_tpm, Skcos_SGNC, Skcos_GeneList]=STD.unPickleAll(Skcos_Pk_Count, PickleOutDir)




#---- Si-related genes *************************************

Pfile='/Users/harrietalexander/Dropbox/NB_141020/Scripts/All_Genes_Paperv5.tab'
Preader=csv.reader(open(Pfile),delimiter='\t')

Phash={}
for line in Preader:
	key = line[0].strip()
	item=line[1].strip()
	if key in Phash: 
		Phash[key].append(item)
	else:
		Phash[key]=[item]


snames=['S1', 'S2', 'S3', 'S4', 'S5']
inames=['+N','-N','+P','-P', 'C']
x=range(10)
outDir='/Users/harrietalexander/Dropbox/NB_141020/FinalSingleGeneFigures/'
N=1
for ref in Phash:
	N+=1
	F=plt.figure(N)
	F.set_size_inches(5,5)
	ax1=F.add_subplot(111)
	ax1.set_xlim([-.5, 3.5])
	ax1.set_xticks(x[:5])
	ax1.set_xticklabels(inames)
	ax2=ax1.twinx()
	ax2.set_xlim([-.5, 3.5])
	ax2.set_xticklabels(inames)
	for item in Phash[ref]:

# 		ax2.set_xlim([4.5, 9.5])
# 		ax2.set_xticks(x[5:])
# 		ax2.set_xticklabels(inames)
# 		ax1.set_ylim([-20,20])
		##ax1.set_ylim([0,10])
		#ax2.set_ylim([0,0.4])
		bmap=brewer2mpl.get_map('RdBu', 'Diverging', 5)
		bmap=bmap.hex_colors
		PUpNDn='#FF33CC'
		NUp=bmap[0]
		NDn=bmap[1]
		PUp=bmap[4]
		PDn=bmap[3]
		NRG='0.75'
		Throt_UpPDnN=list(set(Throt_GeneList['P_Genes'][1]).intersection(Throt_GeneList['N_Genes'][0]))
		Skcos_UpPDnN=list(set(Skcos_GeneList['P_Genes'][1]).intersection(Skcos_GeneList['N_Genes'][0]))

		
		
		Throt_SGNC=Throt_SGNC
		Skcos_SGNC=Skcos_SGNC
		if re.search('Throt', item):	
			if any(item==s for s in Throt_UpPDnN):
				ax2.plot(x[:4],Throt_SGNC[item][6:], ls='--', color=PUpNDn, marker='o', mec=PUpNDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PUpNDn, marker='o', mec=PUpNDn, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['P_Genes'][1]):
			 	ax2.plot(x[:4],Throt_SGNC[item][6:], ls='--', color=PUp, marker='o', mec=PUp, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PUp, marker='o', mec=PUp, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['P_Genes'][0]):
			 	ax2.plot(x[:4],Throt_SGNC[item][6:],ls='--', color=PDn, marker='o', mec=PDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=PDn, marker='o', mec=PDn, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['N_Genes'][1]):
			 	ax2.plot(x[:4],Throt_SGNC[item][6:], ls='--',color=NUp, marker='o', mec=NUp, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None', color=NUp, marker='o', mec=NUp, ms=12,linewidth=3)
			elif any(item==s for s in Throt_GeneList['N_Genes'][0]):
			 	ax2.plot(x[:4],Throt_SGNC[item][6:], ls='--', color=NDn, marker='o', mec=NDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=NDn, marker='o', mec=NDn, ms=12,linewidth=3)
			else:
				ax2.plot(x[:4],Throt_SGNC[item][6:], ls='--',color=NRG, marker='o',mec=NRG, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Throt_SGNC[item][5:],ls='None',color=NRG, marker='o',mec=NRG, ms=12,linewidth=3)
			 	

		elif re.search('Skcos', item):
			if any(item==s for s in Skcos_UpPDnN):
				ax1.plot(x[:4],Skcos_SGNC[item][6:], ls='-', color=PUpNDn, marker='^', mec=PUpNDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PUpNDn, marker='^', mec=PUpNDn, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['P_Genes'][1]):
			 	ax1.plot(x[:4],Skcos_SGNC[item][6:], ls='-', color=PUp, marker='^', mec=PUp, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PUp, marker='^', mec=PUp, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['P_Genes'][0]):
			 	ax1.plot(x[:4],Skcos_SGNC[item][6:],ls='-', color=PDn, marker='^', mec=PDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=PDn, marker='^', mec=PDn, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['N_Genes'][1]):
			 	ax1.plot(x[:4],Skcos_SGNC[item][6:], ls='-',color=NUp, marker='^', mec=NUp, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None', color=NUp, marker='^', mec=NUp, ms=12,linewidth=3)
			elif any(item==s for s in Skcos_GeneList['N_Genes'][0]):
			 	ax1.plot(x[:4],Skcos_SGNC[item][6:], ls='-', color=NDn, marker='^', mec=NDn, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=NDn, marker='^', mec=NDn, ms=12,linewidth=3)
			else:
				ax1.plot(x[:4],Skcos_SGNC[item][6:], ls='-',color=NRG, marker='^',mec=NRG, ms=10,linewidth=3)
# 			 	ax2.plot(x[5:],Skcos_SGNC[item][5:],ls='None',color=NRG, marker='^',mec=NRG, ms=12,linewidth=3)
			 	
# 	ax1.set_xlabel('Sample',fontsize=14)
# 	ax1.set_ylabel('STD-N', fontsize=14)
	ax1.set_ylim(0, ax1.get_ylim()[1])
	ax2.set_ylim(0, ax2.get_ylim()[1])
	plt.suptitle(ref,fontsize=16)
	plt.savefig(outDir+ref+'140819_SGNC.pdf')

plt.show()

# %%
import pandas as pd

# %%
Skcos_SGNC['Skcos1']
# Out:
# [0.03313993628798799,
#  0.048043073100020706,
#  0.0378657487091222,
#  0.0901023890784983,
#  0.02009329027628274,
#  0.022674568410203558,
#  0.023856858846918485,
#  0.02415875754961173,
#  0.02237136465324385,
#  0.01363040629095675]

# %%
import math
import sys
import glob
import os
import numpy as np
import re
import csv
import matplotlib.pylab as plt
import matplotlib.cm as cm
import STD_Functions as STD
import General_STD_analysis_control as GSTD
import pickle
import matplotlib as mpl
import brewer2mpl
mpl.rcParams['pdf.fonttype'] = 42
#Relies upon the Genearl and STD_functions python files. 
#Location of pickled files
PickleOutDir="/Users/harrietalexander/Dropbox/NB_141020/PickledData/"

#Throt_filenames from pickle
Throt_Pk_Count=['Throt_raw', 'Throt_tpm', 'Throt_SGNC', 'Throt_GeneList']
Throt_Pk_STD=['Throt_PupP_STD', 'Throt_PupN_STD', 'Throt_PdnP_STD', 'Throt_PdnN_STD', 'Throt_NupP_STD', 'Throt_NupN_STD', 'Throt_NdnP_STD', 'Throt_NdnN_STD', 'Throt_All_P', 'Throt_All_N']

#Skcos Raw Data

#Skcos filenames from pickle
Skcos_Pk_Count=['Skcos_raw', 'Skcos_tpm', 'Skcos_SGNC', 'Skcos_GeneList']
Skcos_Pk_STD=['Skcos_PupP_STD', 'Skcos_PupN_STD', 'Skcos_PdnP_STD', 'Skcos_PdnN_STD', 'Skcos_NupP_STD', 'Skcos_NupN_STD', 'Skcos_NdnP_STD', 'Skcos_NdnN_STD', 'Skcos_All_P', 'Skcos_All_N']

#Get STD_all-- from pickle. 
[Throt_raw, Throt_tpm, Throt_SGNC, Throt_GeneList]=STD.unPickleAll(Throt_Pk_Count, PickleOutDir)

[Throt_PupP_STD, Throt_PupN_STD, Throt_PdnP_STD, Throt_PdnN_STD, Throt_NupP_STD, Throt_NupN_STD, Throt_NdnP_STD, Throt_NdnN_STD, Throt_All_P, Throt_All_N]=STD.unPickleAll(Throt_Pk_STD, PickleOutDir)
[Skcos_PupP_STD, Skcos_PupN_STD, Skcos_PdnP_STD, Skcos_PdnN_STD, Skcos_NupP_STD, Skcos_NupN_STD, Skcos_NdnP_STD, Skcos_NdnN_STD, Skcos_All_P, Skcos_All_N]=STD.unPickleAll(Skcos_Pk_STD, PickleOutDir)


[Skcos_raw, Skcos_tpm, Skcos_SGNC, Skcos_GeneList]=STD.unPickleAll(Skcos_Pk_Count, PickleOutDir)

# %%
#Convert to pandas dictionary
dfSkcos_SGNC=pd.DataFrame(Skcos_SGNC,columns=Skcos_SGNC.keys(),index=['S1', 'S2', 'S3', 'S4', 'S5','+N','-N','+P','-P', 'C'],dtype=float)
dfSkcos_SGNC=dfSkcos_SGNC.T
dfThrot_SGNC=pd.DataFrame(Throt_SGNC,columns=Throt_SGNC.keys(),index=['S1', 'S2', 'S3', 'S4', 'S5','+N','-N','+P','-P', 'C'],dtype=float)
dfThrot_SGNC=dfThrot_SGNC.T

# %%
#UpPNovel	Skcos2786
#UpPNovel	Throt2274

UpPS=dfSkcos_SGNC.loc['Skcos2786',['-P','+P']]
UpPT=dfThrot_SGNC.loc['Throt2274',['-P','+P']]

fig = plt.figure()
fig.set_size_inches(3,4)
ax = fig.add_subplot(111)

N = 1
menMeans = [UpPT['+P']]
womenMeans = [UpPT['-P']]
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars

rects1 = ax.bar(ind, menMeans, width,
                color='black')

rects2 = ax.bar(ind+width, womenMeans, width,
                    color='red')

ax.set_xticks([0,1])
fig.savefig('Throt_P_Barplot.pdf')

fig2 = plt.figure()
fig2.set_size_inches(3,4)
ax2 = fig2.add_subplot(111)

N = 1
menMeans = [UpPS['+P']]
womenMeans = [UpPS['-P']]
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars

rects1 = ax2.bar(ind, menMeans, width,
                color='black')

rects2 = ax2.bar(ind+width, womenMeans, width,
                    color='red')
ax2.set_xticks([0,1])
fig2.savefig('Skeletonema_P_Barplot.pdf')

# %%
# NovelN  Throt187
# NovelN  Throt421
# NovelN  Skcos397


UpPT=dfThrot_SGNC.loc['Throt6351',['-N','+N']]
UpPS=dfSkcos_SGNC.loc['Skcos7787',['-N','+N']]

fig = plt.figure()
ax = fig.add_subplot(111)
fig.set_size_inches(3,4)
ax.set_xticks([0,1])
N = 1
menMeans = [UpPS['+N']]
womenMeans = [UpPS['-N']]
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars

rects1 = ax.bar(ind, menMeans, width,
                color='black')

rects2 = ax.bar(ind+width, womenMeans, width,
                    color='red')
fig.savefig('Skcos_N_Bar.pdf')
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
fig2.set_size_inches(3,4)

N = 1
menMeans = [UpPT['+N']]
womenMeans = [UpPT['-N']]
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars
ax2.set_xticks([0,1])

rects1 = ax2.bar(ind, menMeans, width,
                color='black')

rects2 = ax2.bar(ind+width, womenMeans, width,
                    color='red')
fig2.savefig('Throt_N_Bar.pdf')

# %%
TNvlN=Throt_All_N['Throt6351']

# %%
SNvlN=Skcos_All_N['Skcos22648']
SNvlN
# Out:
# [0.9914529443956883,
#  -9.886293040155122,
#  0.9797579930110051,
#  -0.6858206639776606,
#  1.0,
#  0.7225545097104731]

# %%
snames=['S1', 'S2', 'S3', 'S4', 'S5']
inames=['+N','-N','+P','-P', 'C']
x=range(10)
outDir='/Users/harrietalexander/Dropbox/NB_Paper/SingleGenePlots_v2/'
N=1
N+=1
F=plt.figure(N)
F.set_size_inches(5,4)
from matplotlib import gridspec
gs = gridspec.GridSpec(2, 1,
                       height_ratios=[2,1]
                       )

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
# ax1.set_xticks(range(5))
# ax2.set_xticks(range(5))
ax1.plot(x[:5],SNvlN[:5], ls='--', color=PUpNDn, marker='^', mec=PUpNDn, ms=10,linewidth=3)
ax1.plot(x[:5],TNvlN[:5], ls='--', color=PUpNDn, marker='o', mec=PUpNDn, ms=10,linewidth=3)
ax2.plot(x[:5],SNvlN[:5], ls='--', color=PUpNDn, marker='^', mec=PUpNDn, ms=10,linewidth=3)
ax2.plot(x[:5],TNvlN[:5], ls='--', color=PUpNDn, marker='o', mec=PUpNDn, ms=10,linewidth=3)
ax1.set_ylim(-1.25,2.5) # outliers only
ax2.set_ylim(-10.5,-8.5) # most of the data
ax1.set_xlim(-0.5,4.5) # outliers only
ax2.set_xlim(-0.5,4.5) # most of the data
ax1.set_yticks(np.arange(-1,2.5))
ax2.set_yticks(np.arange(-10,-8))
ax1.set_xticklabels(snames)
ax1.set_xticklabels(snames)

ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop='off') # don't put tick labels at the top
ax2.xaxis.tick_bottom()

d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
ax1.plot((-d,+d),(-d,+d), **kwargs)      # top-left diagonal
ax1.plot((1-d,1+d),(-d,+d), **kwargs)    # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d),(1-d,1+d), **kwargs)   # bottom-left diagonal
ax2.plot((1-d,1+d),(1-d,1+d), **kwargs) # bottom-right diagonal
ax2.set_xticks(range(5))
ax1.set_xticklabels(snames)
ax2.set_xticklabels(snames)

F.savefig(outDir+'NovelN_141009.pdf')

# %%
"""
Broken axis example, where the y-axis will have a portion cut out.
"""
import matplotlib.pylab as plt
import numpy as np


# 30 points between 0 0.2] originally made using np.random.rand(30)*.2
pts = np.array([ 0.015,  0.166,  0.133,  0.159,  0.041,  0.024,  0.195,
    0.039, 0.161,  0.018,  0.143,  0.056,  0.125,  0.096,  0.094, 0.051,
    0.043,  0.021,  0.138,  0.075,  0.109,  0.195,  0.05 , 0.074, 0.079,
    0.155,  0.02 ,  0.01 ,  0.061,  0.008])

# Now let's make two outlier points which are far away from everything.
pts[[3,14]] += .8

# If we were to simply plot pts, we'd lose most of the interesting
# details due to the outliers. So let's 'break' or 'cut-out' the y-axis
# into two portions - use the top (ax) for the outliers, and the bottom
# (ax2) for the details of the majority of our data
f,(ax,ax2) = plt.subplots(2,1,sharex=True)

# plot the same data on both axes
ax.plot(pts)
ax2.plot(pts)

# zoom-in / limit the view to different portions of the data
ax.set_ylim(.78,1.) # outliers only
ax2.set_ylim(0,.22) # most of the data

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off') # don't put tick labels at the top
ax2.xaxis.tick_bottom()

# This looks pretty good, and was fairly painless, but you can get that
# cut-out diagonal lines look with just a bit more work. The important
# thing to know here is that in axes coordinates, which are always
# between 0-1, spine endpoints are at these locations (0,0), (0,1),
# (1,0), and (1,1).  Thus, we just need to put the diagonals in the
# appropriate corners of each of our axes, and so long as we use the
# right transform and disable clipping.

d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d,+d),(-d,+d), **kwargs)      # top-left diagonal
ax.plot((1-d,1+d),(-d,+d), **kwargs)    # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d),(1-d,1+d), **kwargs)   # bottom-left diagonal
ax2.plot((1-d,1+d),(1-d,1+d), **kwargs) # bottom-right diagonal

# What's cool about this is that now if we vary the distance between
# ax and ax2 via f.subplots_adjust(hspace=...) or plt.subplot_tool(),
# the diagonal lines will move accordingly, and stay right at the tips
# of the spines they are 'breaking'

plt.show()

# %%
from matplotlib import gridspec
gs = gridspec.GridSpec(2, 1,
                       width_ratios=[1,1],
                       height_ratios=[4,1]
                       )

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

# %% [markdown]
# ##
